# %%
import pandas as pd
schema = pd.read_csv('d:/datanews/kaggle-survey-2017/schema.csv')

# %%
schema
# Out:
#                                 Column  \
# 0                         GenderSelect
# 1                       GenderFreeForm
# 2                              Country
# 3                                  Age
# 4                     EmploymentStatus
# 5                        StudentStatus
# 6                  LearningDataScience
# 7             KaggleMotivationFreeForm
# 8                           CodeWriter
# 9                       CareerSwitcher
# 10               CurrentJobTitleSelect
# 11             CurrentJobTitleFreeForm
# 12                            TitleFit
# 13                 CurrentEmployerType
# 14                MLToolNextYearSelect
# 15              MLToolNextYearFreeForm
# 16              MLMethodNextYearSelect
# 17            MLMethodNextYearFreeForm
# 18        LanguageRecommendationSelect
# 19      LanguageRecommendationFreeForm
# 20                PublicDatasetsSelect
# 21              PublicDatasetsFreeForm
# 22   PersonalProjectsChallengeFreeForm
# ...

# %%
questions=schema['Column']
for x in questions : 
  print(x)
# Out:
# GenderSelect
# GenderFreeForm
# Country
# Age
# EmploymentStatus
# StudentStatus
# LearningDataScience
# KaggleMotivationFreeForm
# CodeWriter
# CareerSwitcher
# CurrentJobTitleSelect
# CurrentJobTitleFreeForm
# TitleFit
# CurrentEmployerType
# MLToolNextYearSelect
# MLToolNextYearFreeForm
# MLMethodNextYearSelect
# MLMethodNextYearFreeForm
# LanguageRecommendationSelect
# LanguageRecommendationFreeForm
# PublicDatasetsSelect
# PublicDatasetsFreeForm
# PersonalProjectsChallengeFreeForm
# LearningPlatformSelect
# LearningPlatformCommunityFreeForm
# LearningPlatformFreeForm1
# LearningPlatformFreeForm2
# LearningPlatformFreeForm3
# LearningPlatformUsefulnessArxiv
# LearningPlatformUsefulnessBlogs
# LearningPlatformUsefulnessCollege
# LearningPlatformUsefulnessCompany
# LearningPlatformUsefulnessConferences
# LearningPlatformUsefulnessFriends
# LearningPlatformUsefulnessKaggle
# LearningPlatformUsefulnessNewsletters
# LearningPlatformUsefulnessCommunities
# ...

# %%
response= pd.read_csv('d:/datanews/kaggle-survey-2017/multipleChoiceResponses.csv', encoding='gbk')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
response
# Out:
#                                             GenderSelect  \
# 0      Non-binary, genderqueer, or gender non-conforming
# 1                                                 Female
# 2                                                   Male
# 3                                                   Male
# 4                                                   Male
# 5                                                   Male
# 6                                                   Male
# 7                                                 Female
# 8                                                 Female
# 9                                                   Male
# 10                                                Female
# 11                                                  Male
# 12                                                  Male
# 13                                                  Male
# 14                                                  Male
# ...

# %% [markdown]
# # 思考角度：
# 1.年龄、性别
# 2.薪水：不同年龄的薪水，不同国家的薪水，不同性别的薪水，不同职业的薪水
# 3.专业：
# 4.语言：现在使用较多的语言；将来使用较多的语言；不同职业使用的语言；不同年龄使用的语言
# 5.工作中各部分所耗费的时间

# %%
response.dropna()
# Out:
# Empty DataFrame
# ...

# %%
response.sort_values(by='Age')
# Out:
#                                             GenderSelect  \
# 11221                                             Female
# 15707                                               Male
# 5186                                                Male
# 5067                                A different identity
# 160                                 A different identity
# 7862                                                Male
# 2584                                              Female
# 14324                               A different identity
# 997                                                 Male
# 8096   Non-binary, genderqueer, or gender non-conforming
# 14893                                               Male
# 2176                                A different identity
# 16638                                               Male
# 5018                                                Male
# 7519                                                Male
# ...

# %%
response.describe()
# Out:
#                 Age  LearningCategorySelftTaught  \
# count  16385.000000                 13109.000000
# mean      32.372841                    33.366771
# std       10.473487                    25.787181
# min        0.000000                     0.000000
# 25%       25.000000                    15.000000
# 50%       30.000000                    30.000000
# 75%       37.000000                    50.000000
# max      100.000000                   100.000000
#
#        LearningCategoryOnlineCourses  LearningCategoryWork  \
# count                   13126.000000          13111.000000
# mean                       27.375514             15.217593
# std                        26.860840             18.996778
# min                         0.000000              0.000000
# 25%                         5.000000              0.000000
# 50%                        20.000000             10.000000
# 75%                        40.000000             25.000000
# ...

# %%
# %matplotlib inline 
# This is a bit of magic to make matplotlib figures appear inline in the notebook
# rather than in a new window.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
pd.set_option('max_rows', 25)
# 显示的最大行数和列数，如果超额就显示省略号，这个指的是多少个dataFrame的列。如果比较多又不允许换行，就会显得很乱。
plt.style.use('ggplot') #？
plt.rcParams["figure.figsize"] = (10, 4) #？

# %%
columns = response.columns
for x in columns : 
  print(x) 

#数据太大了，有些columns会被隐藏看不到，写了简单的for循环就能打印出来
# Out:
# GenderSelect
# Country
# Age
# EmploymentStatus
# StudentStatus
# LearningDataScience
# CodeWriter
# CareerSwitcher
# CurrentJobTitleSelect
# TitleFit
# CurrentEmployerType
# MLToolNextYearSelect
# MLMethodNextYearSelect
# LanguageRecommendationSelect
# PublicDatasetsSelect
# LearningPlatformSelect
# LearningPlatformUsefulnessArxiv
# LearningPlatformUsefulnessBlogs
# LearningPlatformUsefulnessCollege
# LearningPlatformUsefulnessCompany
# LearningPlatformUsefulnessConferences
# LearningPlatformUsefulnessFriends
# LearningPlatformUsefulnessKaggle
# LearningPlatformUsefulnessNewsletters
# LearningPlatformUsefulnessCommunities
# LearningPlatformUsefulnessDocumentation
# LearningPlatformUsefulnessCourses
# LearningPlatformUsefulnessProjects
# LearningPlatformUsefulnessPodcasts
# LearningPlatformUsefulnessSO
# LearningPlatformUsefulnessTextbook
# LearningPlatformUsefulnessTradeBook
# LearningPlatformUsefulnessTutoring
# LearningPlatformUsefulnessYouTube
# BlogsPodcastsNewslettersSelect
# ...

# %%
response['TimeGatheringData']
# Out:
# 0         0.0
# 1         NaN
# 2         NaN
# 3        50.0
# 4        30.0
# 5        60.0
# 6        30.0
# 7         NaN
# 8        60.0
# 9        40.0
# 10        NaN
# 11       30.0
#          ...
# 16704     NaN
# 16705     NaN
# 16706     NaN
# 16707     NaN
# 16708     NaN
# 16709     NaN
# 16710     NaN
# 16711     NaN
# 16712    50.0
# 16713     NaN
# 16714     NaN
# 16715     NaN
# Name: TimeGatheringData, Length: 16716, dtype: float64

# %%
print(response.loc[1500]) #切片取1500行
# Out:
# GenderSelect                                                                   Male
# Country                                                                       India
# Age                                                                              31
# EmploymentStatus                                                 Employed full-time
# StudentStatus                                                                   NaN
# LearningDataScience                                                             NaN
# CodeWriter                                                                      Yes
# CareerSwitcher                                                                  NaN
# CurrentJobTitleSelect                                                Data Scientist
# TitleFit                                                                       Fine
# CurrentEmployerType               Employed by professional services/consulting firm
# ...

# %%
print(response.loc[1400])
# Out:
# GenderSelect                                                                   Male
# Country                                                                       Japan
# Age                                                                              26
# EmploymentStatus                                                 Employed full-time
# StudentStatus                                                                   NaN
# LearningDataScience                                                             NaN
# CodeWriter                                                                      Yes
# CareerSwitcher                                                                  NaN
# CurrentJobTitleSelect                                                  Data Analyst
# TitleFit                                                                        NaN
# CurrentEmployerType               Employed by professional services/consulting firm
# ...

# %%
response.loc[:,['MLToolNextYearSelect','CurrentJobTitleSelect']] #切片，保留'MLToolNextYearSelect,CurrentJobTitleSelect两行
# Out:
#               MLToolNextYearSelect                 CurrentJobTitleSelect
# 0                         SAS Base                 DBA/Database Engineer
# 1                           Python                                   NaN
# 2              Amazon Web services                                   NaN
# 3                       TensorFlow      Operations Research Practitioner
# 4                       TensorFlow                    Computer Scientist
# 5                       TensorFlow                        Data Scientist
# 6                       TensorFlow                    Computer Scientist
# 7             Google Cloud Compute  Software Developer/Software Engineer
# 8      Microsoft Excel Data Mining                      Business Analyst
# 9                            C/C++  Software Developer/Software Engineer
# 10                          Python                                   NaN
# 11                           Other                        Data Scientist
# ...

# %%
response.iloc[2,5]=np.nan #替换
print(response)
# Out:
#                                             GenderSelect  \
# 0      Non-binary, genderqueer, or gender non-conforming
# 1                                                 Female
# 2                                                   Male
# 3                                                   Male
# 4                                                   Male
# 5                                                   Male
# 6                                                   Male
# 7                                                 Female
# 8                                                 Female
# 9                                                   Male
# 10                                                Female
# 11                                                  Male
# ...                                                  ...
# 16704                                               Male
# 16705                                               Male
# ...

# %% [markdown]
# # Gender

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import squarify  
# Pure Python implementation of the squarify treemap layout algorithm.
#Based on algorithm from Bruls, Huizing, van Wijk, "Squarified Treemaps", but implements it differently.

# %%
plt.subplots(figsize=(22,12))
sns.countplot(y=response['GenderSelect'],order=response['GenderSelect'].value_counts().index)
plt.show() 

#需要做的工作：如何调大标签的字；了解seaborn的基本用法

# %%
gender_count=response['GenderSelect'].value_counts()
gender_count
# Out:
# Male                                                 13610
# Female                                                2778
# A different identity                                   159
# Non-binary, genderqueer, or gender non-conforming       74
# Name: GenderSelect, dtype: int64

# %%
df = pd.DataFrame(response['GenderSelect'].value_counts().values,
                  index=response['GenderSelect'].value_counts().index, 
                  columns=[' '])

df.plot(kind='pie', subplots=True, autopct='%1.0f%%', figsize=(8, 8))
#plt.subplots_adjust(wspace=0.5)
plt.show()

# %% [markdown]
# # Country

# %%
resp_coun=response['Country'].value_counts()[:10].to_frame()
resp_coun
# Out:
#                              Country
# United States                   4197
# India                           2704
# Other                           1023
# Russia                           578
# United Kingdom                   535
# People 's Republic of China      471
# Brazil                           465
# Germany                          460
# France                           442
# Canada                           440

# %%
resp_coun=response['Country'].value_counts()[:10].to_frame()
sns.barplot(resp_coun['Country'],resp_coun.index,palette='inferno')
plt.title('Top 10 Countries by number of respondents')
plt.xlabel('')
fig=plt.gcf()
fig.set_size_inches(10,8)
plt.show()

#也可画成热力图
#tree=response['Country'].value_counts().to_frame()
#squarify.plot(sizes=tree['Country'].values,label=tree.index,color=sns.color_palette('RdYlGn_r',52))
#plt.rcParams.update({'font.size':20})
#fig=plt.gcf()
#fig.set_size_inches(40,15)
#plt.show()

# %% [markdown]
# # Salary

# %%
response[['CompensationAmount','CompensationCurrency']]
# Out:
#       CompensationAmount CompensationCurrency
# 0                    NaN                  NaN
# 1                    NaN                  NaN
# 2                    NaN                  NaN
# 3                250,000                  USD
# 4                    NaN                  NaN
# 5                    NaN                  NaN
# 6                    NaN                  NaN
# 7                    NaN                  NaN
# 8                  80000                  AUD
# 9                1200000                  RUB
# 10                   NaN                  NaN
# 11                95,000                  INR
# ...                  ...                  ...
# 16704                NaN                  NaN
# 16705                NaN                  NaN
# 16706                NaN                  NaN
# 16707                NaN                  NaN
# 16708                NaN                  NaN
# 16709                NaN                  NaN
# ...

# %%
print(response.CompensationAmount)
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3        250,000
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8          80000
# 9        1200000
# 10           NaN
# 11        95,000
#           ...
# 16704        NaN
# 16705        NaN
# 16706        NaN
# 16707        NaN
# 16708        NaN
# 16709        NaN
# 16710        NaN
# 16711        NaN
# 16712        NaN
# 16713        NaN
# 16714        NaN
# 16715        NaN
# Name: CompensationAmount, Length: 16716, dtype: object

# %%
response['CompensationAmount']=response['CompensationAmount'].str.replace(',','')
response['CompensationAmount']=response['CompensationAmount'].str.replace('-','')
rates=pd.read_csv('D:datanews/kaggle-survey-2017/conversionRates.csv')
rates.drop('Unnamed: 0',axis=1,inplace=True)
salary=response[['CompensationAmount','CompensationCurrency','GenderSelect','Country','CurrentJobTitleSelect']].dropna()
salary=salary.merge(rates,left_on='CompensationCurrency',right_on='originCountry',how='left')
salary['Salary']=pd.to_numeric(salary['CompensationAmount'])*salary['exchangeRate']
print('Maximum Salary is USD $',salary['Salary'].dropna().astype(int).max())
print('Minimum Salary is USD $',salary['Salary'].dropna().astype(int).min())
print('Median Salary is USD $',salary['Salary'].dropna().astype(int).median()) #显然很多答案是瞎扯 但是平均薪水还是有参考意义的
# Out:
# Maximum Salary is USD $ 208999999
# Minimum Salary is USD $ -2147483648
# Median Salary is USD $ 53812.0

# %%
plt.subplots(figsize=(15,8))
salary=salary[salary['Salary']<1000000]
sns.distplot(salary['Salary'])
plt.title('Salary Distribution',size=15)
plt.show()

# %% [markdown]
# # 考虑ppp

# %%
rates_ppp={'Countries':['United States','India','United Kingdom','Germany','France','Brazil','Canada','Spain','Australia','Russia','Italy',"People 's Republic of China",'Netherlands'],
           'Currency':['USD','INR','GBP','EUR','EUR','BRL','CAD','EUR','AUD','RUB','EUR','CNY','EUR'],
           'PPP':[1.00,17.7,0.7,0.78,0.81,2.05,1.21,0.66,1.46,25.13,0.74,3.51,0.8]}

rates_ppp = pd.DataFrame(data=rates_ppp)
rates_ppp
# Out:
#                       Countries Currency    PPP
# 0                 United States      USD   1.00
# 1                         India      INR  17.70
# 2                United Kingdom      GBP   0.70
# 3                       Germany      EUR   0.78
# 4                        France      EUR   0.81
# 5                        Brazil      BRL   2.05
# 6                        Canada      CAD   1.21
# 7                         Spain      EUR   0.66
# 8                     Australia      AUD   1.46
# 9                        Russia      RUB  25.13
# 10                        Italy      EUR   0.74
# 11  People 's Republic of China      CNY   3.51
# 12                  Netherlands      EUR   0.80

# %%
Salmean = salary.groupby('Country')['Salary'].mean().values
Salcount = salary.groupby('Country')['Country'].count()
Countries = Salcount.index
Salcount = salary.groupby('Country')['Country'].count().values
# Sort by number of respondents
idx = Salcount.argsort()
Countries, Salmean, Salcount = [np.take(x, idx) for x in [Countries, Salmean, Salcount]]

# %%
from plotly.graph_objs import Scatter, Layout
y = np.arange(Salmean.size)
fig, axes = plt.subplots(figsize=(15, 20),ncols=2, sharey=True)
axes[0].barh(y, Salcount, align='center', color=sns.color_palette('winter',15), zorder=10)
axes[0].set(title='Number of respondents per country')
axes[1].barh(y, Salmean, align='center', color=sns.color_palette('winter',15), zorder=10)
axes[1].set(title='Mean Salary')

axes[0].invert_xaxis()
axes[0].set(yticks=y, yticklabels=Countries)
axes[0].yaxis.tick_right()

for ax in axes.flat:
    ax.margins(0.03)
    ax.grid(True)

fig.tight_layout()
fig.subplots_adjust(wspace=0.30)
plt.show()

# %%
y = np.arange(Salmean.size)
fig, axes = plt.subplots(figsize=(15, 20),ncols=2, sharey=True)
axes[0].barh(y, Salcount, align='center', color=sns.color_palette('winter',15), zorder=10)
axes[0].set(title='Number of respondents per country')
axes[1].barh(y, Salmean, align='center', color=sns.color_palette('winter',15), zorder=10)
axes[1].set(title='Mean Salary')

axes[0].invert_xaxis()
axes[0].set(yticks=y, yticklabels=Countries)
axes[0].yaxis.tick_right()

for ax in axes.flat:
    ax.margins(0.05)
    ax.grid(True)

fig.tight_layout()
fig.subplots_adjust(wspace=0.30)
plt.show()

# %% [markdown]
#  cost of living,purchasing power,inflation of every country ！！！！（这周的工作）
#  We know the median salary for each country so we can compare between that and the median income in that country to measure how well is a data scientist paid by the standards of the country he lives in.

# %%
import plotly.plotly as py
import plotly.graph_objs as go
plt.style.use('bmh')
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot
init_notebook_mode(connected=True)
from plotly.graph_objs import *
from mpl_toolkits.mplot3d import axes3d
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
Salmean = salary.groupby('Country').mean()
Salcount = salary.groupby('Country').count()
Top_salary = Salmean.sort_values('Salary', ascending=False).head(50)

# %%
data =  dict(
        type = 'choropleth',
        locations = Top_salary.index,
        locationmode = 'country names',
        z = Top_salary['Salary'],
        text = Top_salary.index,
        colorbar = {'title': 'Mean Salaries per Country '})

# %%
layout = dict( title = 'How much data scientists are paid country-wise',
         geo = dict(showframe = False,
         projection = {'type' : 'Mercator'}))

choromap3 = go.Figure(data = [data],layout=layout)
iplot(choromap3)
# Out:
# <div id="fa0d717b-25b8-4a3f-8eb5-7755fd3f897d" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("fa0d717b-25b8-4a3f-8eb5-7755fd3f897d", [{"type": "choropleth", "locations": ["United States", "Switzerland", "Australia", "Norway", "Israel", "United Kingdom", "Netherlands", "Germany", "Ireland", "New Zealand", "Canada", "Denmark", "Singapore", "Sweden", "Belgium", "Japan", "France", "Italy", "Finland", "South Africa", "Spain", "Republic of China", "Hong Kong", "Greece", "Other", "South Korea", "Romania", "People 's Republic of China", "Taiwan", "Argentina", "Brazil", "Chile", "Ukraine", "Czech Republic", "Portugal", "Malaysia", "Colombia", "Poland", "Russia", "Mexico", "Turkey", "Belarus", "India", "Vietnam", "Hungary", "Nigeria", "Iran", "Philippines", "Kenya", "Pakistan"], "locationmode": "country nam
# ...

# %% [markdown]
# # Compensation by Country

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
sal_coun=salary.groupby('Country')['Salary'].median().sort_values(ascending=False)[:15].to_frame()
sns.barplot('Salary',sal_coun.index,data=sal_coun,palette='RdYlGn',ax=ax[0])
ax[0].axvline(salary['Salary'].median(),linestyle='dashed')
ax[0].set_title('Highest Salary Paying Countries')
ax[0].set_xlabel('')
max_coun=salary.groupby('Country')['Salary'].median().to_frame()
max_coun=max_coun[max_coun.index.isin(resp_coun.index)]
max_coun.sort_values(by='Salary',ascending=True).plot.barh(width=0.8,ax=ax[1],color=sns.color_palette('RdYlGn'))
ax[1].axvline(salary['Salary'].median(),linestyle='dashed')
ax[1].set_title('Compensation of Top 15 Respondent Countries')
ax[1].set_xlabel('')
ax[1].set_ylabel('')
plt.subplots_adjust(wspace=0.8)
plt.show()

# %% [markdown]
# # Salary By Gender

# %%
# 考虑如何把国家,性别,薪水三个因素放在一起
#年龄与薪水的关系

# %%
plt.subplots(figsize=(10,8))
sns.barplot(y='GenderSelect',x='Salary',data=salary)

# %%
plt.subplots(figsize=(10,8))
sns.barplot(y='GenderSelect',x='Salary',data=salary)
plt.ylabel('')
plt.show()

# %% [markdown]
# # Age

# %%
age = response['Age']
age = age.dropna()
age = age.drop(age.index[(age.values > 65) | (age.values < 12)]).reset_index(drop=True)

# %%
ax=plt.figure(figsize=(30,15))
sns.barplot(x=age.value_counts().index, y=age.value_counts().values)

# %%
plt.subplots(figsize=(15,8))
response['Age'].hist(bins=50,edgecolor='black')
plt.xticks(list(range(0,80,5)))
plt.title('Age Distribution')
plt.show()

# %%
import plotly
import plotly.figure_factory as fig_fact
response= pd.read_csv('d:/datanews/kaggle-survey-2017/multipleChoiceResponses.csv', encoding='ISO-8859-1')
fig = fig_fact.create_distplot([response[response['Age'] > 0]['Age']], ['age'], colors=['#9F0013'])
#py.iplot(fig, filename='Basic Distplot')
sns.distplot(response[response['Age'] > 0]['Age'])
# 画出来和上图差不多 效果较差 下面想画的标度并没有实现
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning:
#
# Columns (31,83,86,87,98,99,109,116,123,124,127,129,130,164) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# # Profession & Major

# %%
f,ax=plt.subplots(1,2,figsize=(25,15))
sns.countplot(y=response['MajorSelect'],ax=ax[0],order=response['MajorSelect'].value_counts().index)
ax[0].set_title('Major',fontsize=20)
ax[0].set_ylabel('')


sns.countplot(y=response['CurrentJobTitleSelect'],ax=ax[1],order=response['CurrentJobTitleSelect'].value_counts().index)
ax[1].set_title('Current Job',fontsize=20)
ax[1].set_ylabel('')

plt.subplots_adjust(wspace=0.8)

plt.xticks(fontsize=20)
plt.yticks(fontsize=20)
plt.show()

# %% [markdown]
# # Compensation By Job Title

# %%
sal_job=salary.groupby('CurrentJobTitleSelect')['Salary'].median().to_frame()
ax=salary.groupby('CurrentJobTitleSelect')['Salary'].median().sort_values(ascending=True).plot.barh(width=0.9,color=sns.color_palette('inferno',10))
plt.title('Compensation By Job Title',size=15)
for i, v in enumerate(sal_job.Salary): 
    ax.text(.5, i, v,fontsize=10,color='pink',weight='bold')
fig=plt.gcf()
fig.set_size_inches(8,8)
plt.show()

# %% [markdown]
# # preferred language

# %%
f,ax=plt.subplots(1,2,figsize=(15,7))

sns.barplot( y = response['LanguageRecommendationSelect'].value_counts().head(10).index,
            x =response['LanguageRecommendationSelect'].value_counts().head(10).values,
                palette="GnBu_d",ax=ax[0])
ax[0].set_title("Preferred Language by Data scientist")

# %%
#f, ax = plt.subplots(figsize=(15, 7)) 



df = pd.DataFrame(response['LanguageRecommendationSelect'].value_counts().head(10).values,
                  index=response['LanguageRecommendationSelect'].value_counts().head(10).index, 
                  columns=[' '])
ax[1].set_title("Preferred Language share")
df.plot(kind='pie', subplots=True, autopct='%1.0f%%', ax=ax[1])
#plt.subplots_adjust(wspace=0.5)
plt.show()

# 把两个分开跑
# 缩小tag

# %%
f, ax = plt.subplots(figsize=(15, 7)) 
g = sns.barplot( y = response['MLToolNextYearSelect'].value_counts().head(10).index,
            x = response['MLToolNextYearSelect'].value_counts().head(10).values,
                palette="GnBu_d")
plt.title("Machine Learning tool interested to learn next year")
plt.show()

# %% [markdown]
# 在下年想要使用的机器学习语言也许反映了将来语言使用的一个发展

# %%
#这两个维度是否能结合在一起？

# %%
import matplotlib.gridspec as gridspec
v_features = response.ix[:,166:172].columns
plt.figure(figsize=(20,15))
gs = gridspec.GridSpec(3, 2)
for i, cn in enumerate(response[v_features]):
    ax = plt.subplot(gs[i])
    sns.kdeplot(response[str(cn)].dropna(), shade=True, color="r")
    ax.set_title('Time needed for ' + str(cn)[4:])
    ax.set_xlabel(' ')
    ax.set_ylabel(' ')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DeprecationWarning:
#
#
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated

# %%
# 横轴和纵轴分别指的是什么
#  画出中位数或者众数是否能更好的表达· 比较各个过程耗费的时间
#如何改成竖排

# %% [markdown]
# # 是不是不同年龄的人会对不同语言有所偏好？

# %% [markdown]
# # Major

# %%
plt.figure(figsize=(6,8))
sns.countplot(y='MajorSelect', data=response)

# %% [markdown]
# 从事这一职业的的人本科时的专业大多集中在计算机科学，工程（非计算机），数学或者统计，这个想从事这一行业的人一个在专业选择上的参考。

# %% [markdown]
# # Employment Status

# %%
response['EmploymentStatus'].value_counts()
# Out:
# Employed full-time                                      10897
# Not employed, but looking for work                       2110
# Independent contractor, freelancer, or self-employed     1330
# Not employed, and not looking for work                    924
# Employed part-time                                        917
# I prefer not to say                                       420
# Retired                                                   118
# Name: EmploymentStatus, dtype: int64

# %%
sns.countplot(y='EmploymentStatus', data=response) # 这个写法真的很方便

# %% [markdown]
# 大部分都为全职，这是一个好事情。说明这个行业的就业前景不错。（？更好的描述？）

# %% [markdown]
# # Programming Experience

# %%
sns.countplot(y='Tenure', data=response)

# %% [markdown]
# # FirstTraining

# %%
import plotly.offline as py
import plotly.figure_factory as fig_fact
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.plotly as pp
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
train =response['FirstTrainingSelect'].value_counts()
label = (np.array(train.index))
size = (np.array((train / train.sum())*100))

# %%
colors = ['skygreen', 'skyblue', '#96D38C', '#D0F9B1', 'khaki', 'grey']
trace = go.Pie(labels=label, values=size, marker=dict(colors=colors))
layout = go.Layout(
    title='First Training Platform'
)
data = [trace]
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename="train")
# Out:
# <div id="91dc1dcc-fa9e-4aff-956f-d52e3f678c10" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("91dc1dcc-fa9e-4aff-956f-d52e3f678c10", [{"type": "pie", "labels": ["Online courses (coursera, udemy, edx, etc.)", "University courses", "Self-taught", "Work", "Other", "Kaggle competitions"], "values": [36.01821642196846, 28.28983143012507, 25.129146275149537, 6.729200652528548, 2.0867319195214793, 1.7468733007069062], "marker": {"colors": ["skygreen", "skyblue", "#96D38C", "#D0F9B1", "khaki", "grey"]}}], {"title": "First Training Platform"}, {"showLink": true, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# # 学历

# %%
response['FormalEducation'].value_counts()
# Out:
# Master's degree                                                      6273
# Bachelor's degree                                                    4811
# Doctoral degree                                                      2347
# Some college/university study without earning a bachelor's degree     786
# Professional degree                                                   451
# I did not complete any formal education past high school              257
# I prefer not to answer                                                 90
# Name: FormalEducation, dtype: int64

# %%
response['ParentsEducation'].value_counts()
# Out:
# A bachelor's degree                                    3605
# A master's degree                                      2903
# High school                                            1973
# Some college/university study, no bachelor's degree    1216
# A doctoral degree                                      1119
# Primary/elementary school                               684
# A professional degree                                   645
# I prefer not to answer                                  259
# I don't know/not sure                                   140
# No education                                            124
# Name: ParentsEducation, dtype: int64

# %% [markdown]
# # profession & Python /R

# %%
MLToolNextYearSelect

# %%
data = response[(response['CurrentJobTitleSelect'].notnull()) & ((response['LanguageRecommendationSelect'] == 'Python') | (response['LanguageRecommendationSelect'] == 'R'))]
plt.figure(figsize=(12, 10))
sns.countplot(y="CurrentJobTitleSelect", hue="LanguageRecommendationSelect", data=data)

# %% [markdown]
# # 对新手的推荐语言

# %%
plt.subplots(figsize=(8,8))
tools=response['WorkToolsSelect'].str.split(',')
tools_work=[]
for i in tools.dropna():
    tools_work.extend(i)
pd.Series(tools_work).value_counts()[:15].sort_values(ascending=True).plot.barh(width=0.9,color=sns.color_palette('RdYlGn',15))
plt.show()

# %%
response['LanguageRecommendationSelect'].value_counts()[:2].plot.bar()
plt.show()

# %%
resp=response.dropna(subset=['WorkToolsSelect'])
resp=resp.merge(rates,left_on='CompensationCurrency',right_on='originCountry',how='left')
resp
# Out:
#                                            GenderSelect        Country   Age  \
# 0     Non-binary, genderqueer, or gender non-conforming            NaN   NaN
# 1                                                  Male  United States  56.0
# 2                                                  Male         Taiwan  38.0
# 3                                                  Male         Brazil  46.0
# 4                                                  Male  United States  35.0
# 5                                                Female      Australia  43.0
# 6                                                  Male         Russia  33.0
# 7                                                  Male          India  27.0
# 8                                                  Male         Taiwan  26.0
# 9                                                  Male  United States  58.0
# 10                                                 Male  United States  25.0
# ...

# %%
python=resp[(resp['WorkToolsSelect'].str.contains('Python'))&(~resp['WorkToolsSelect'].str.contains('R'))]
R=resp[(~resp['WorkToolsSelect'].str.contains('Python'))&(resp['WorkToolsSelect'].str.contains('R'))]
both=resp[(resp['WorkToolsSelect'].str.contains('Python'))&(resp['WorkToolsSelect'].str.contains('R'))]

# %%
from matplotlib_venn import venn2
venn2(subsets = (python.shape[0],R.shape[0],both.shape[0]), set_labels = ('Python Users', 'R Users'))
plt.show()

# %%
f,ax=plt.subplots(1,2,figsize=(25,12))
sns.countplot(response['JobSkillImportanceVisualizations'],ax=ax[0])
ax[0].set_title('Job Importance For Visuals')
ax[0].set_xlabel('')
response['WorkDataVisualizations'].value_counts().plot.pie(autopct='%2.0f%%',colors=sns.color_palette('Paired',10),ax=ax[1])
ax[1].set_title('Use Of Visualisations in Projects')
my_circle=plt.Circle( (0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.ylabel('')
plt.show()

# %%
response['LanguageRecommendationSelect'].value_counts()
# Out:
# Python      6941
# R           2643
# SQL          385
# C/C++/C#     307
# Matlab       238
# Java         138
# Scala         94
# SAS           88
# Other         85
# Julia         30
# Stata         28
# Haskell       17
# F#             4
# Name: LanguageRecommendationSelect, dtype: int64

# %%
sns.countplot(y='LanguageRecommendationSelect', data=response)

# %%
# Out:
#   File "<ipython-input-64-2238e7cefca3>", line 2
#     sat_=
#          ^
# SyntaxError: invalid syntax

# %%
response['MLToolNextYearSelect'].value_counts()
# Out:
# TensorFlow                                        2621
# Python                                            1713
# R                                                  910
# Spark / MLlib                                      755
# Hadoop/Hive/Pig                                    417
# Other                                              407
# Amazon Machine Learning                            392
# Jupyter notebooks                                  358
# I don't plan on learning a new tool/technology     341
# Google Cloud Compute                               296
# Amazon Web services                                273
# Julia                                              222
#                                                   ...
# Flume                                               16
# Statistica (Quest/Dell-formerly Statsoft)           15
# Orange                                              15
# KNIME (commercial version)                          14
# ...

# %%
response['MLMethodNextYearSelect'].value_counts()
# Out:
# Deep learning                                  4362
# Neural Nets                                    1386
# Time Series Analysis                            680
# Bayesian Methods                                511
# Text Mining                                     493
# Genetic & Evolutionary Algorithms               425
# Social Network Analysis                         364
# Anomaly Detection                               307
# Ensemble Methods (e.g. boosting, bagging)       269
# Other                                           258
# Monte Carlo Methods                             230
# Regression                                      220
# Cluster Analysis                                216
# I don't plan on learning a new ML/DS method     195
# Decision Trees                                  156
# Random Forests                                  154
# Support Vector Machines (SVM)                   147
# Survival Analysis                               104
# ...

# %%
sns.countplot(y='MLMethodNextYearSelect', data=response)

# %%
sns.countplot(y='TimeSpentStudying', data=response, hue='EmploymentStatus').legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %% [markdown]
# An interesting observation is that Unemployed people form the majority of the group answering this question despite being the minority in the overall population. This group typically should contain students still in college or graduate school.
#
# Most of them tend to study more than 2 hours every week. A considerable fraction of the unemployed put in more than 10 hours of work into learning Data Science.
#
# General Verdict
# In this case, it is really hard to say. In general, you should put in more effort if you're unemployed as compared to when you're in a full time job.

# %% [markdown]
# #如何能够成为一个数据科学家？
